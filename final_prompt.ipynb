# %%
# chatgpt4.0 특이점 prompt
f"""
"타겟 데이터테이블"은 특정 한의원에 대한 데이터이다.
"타겟 데이터테이블"의 컬럼들을 복합적으로 분석해서 큰 특이점 또는 추세를 다양하게 7가지 알려줘.
"타겟 데이터테이블"에 없는 내용은 언급하지마.

- 최근 3개월과 처음 1~3번째 행의 기간이 중요하다. 이 기간동안의 특이점도 언급해줘.
- "신규환자수/총환자수 비율(%)" ,"비급여/총매출 비율(%)","재진환자수/총환자수 비율(%)"의 특이점들도 언급해야한다.
- "Columns explanation"은 타겟 데이터테이블의 각각 컬럼들에 대한 설명이다.
- 반드시 오직 '타겟 데이터테이블'에 있는 내용으로만 분석해야한다.
- 특정 기간이나 날짜에 대해서도 함께 언급해야한다.
- 타겟 데이터테이블의 아래로 갈수록 최근 날짜의 데이터이다.
- "가장"이라는 극단적인 단어 표현 대신, "비교적 크게" 혹은 "비교적 많이"처럼 순화적인 표현을 사용해줘.
- "타겟 데이터테이블"의 "월별 날짜"컬럼에 없는 날짜는 절대 언급하지마.
- "답변예시"는 타겟 데이터테이블에 대한 내용은 아니므로 그냥 답변 양식으로만 참고해줘.

Columns explanation:
    Instructions:
    - 'biz_dt' means '날짜'.
    - 'total_pay' means '총 매출'. It's total sales of medical clinic for a month. It's the sum of '비급여 총매출', '자보매출', '공단청구금', '본인부담금', '기타매출'.
    - 'nonbenefit_total_pay' means '비급여 총매출'. This sales are paid by patient 100%.It is important for medical clinics to induce sales of these items to increase total sales.
    - 'carinsur_pay' means '자보매출'. These sales are sales that auto insurance companies provide medical expenses for patients who come to medical clinics due to traffic accidents.
    - 'nhis_pay' means '공단청구금'. These sales are paid by the Health Care Corporation, etc., which patients who visited the medical clinic joined.
    - 'co_pay' means '본인부담금'. These are the remaining expenses after paying a portion of the patient's medical expenses from the corporation or insurance. It's the sales that the patient pays directly to the hospital.
    - 'etc_pay' means '기타매출'. These are sales that occurred outside of medical treatment.
    - 'visit_cnt' means '환자 수'. This indicates the total number of patients who visited the hospital for a month.
    - 'fstvisit_cnt' means '신규 환자수'. This indicates the number of patients who visited the hospital for the first time.
    - 'revisit_cnt' means '재진 환자수'. This indicates the number of patients for a month, who visitied the hospital before
    - 'fstvisit_cnt/visit_cnt (%)' means '신규 환자수/환자수 (%)'. This is a result of 'fstvisit_cnt' divided by 'visit_cnt'.
    - 'nonbenefit_total_pay/total_pay (%)' means '비급여 총매출/총 매출 (%)'. This is a result of 'nonbenefit_total_pay' divided by 'total_pay'.
    - 'revisit_cnt/visit_cnt (%)' means '재진 환자수/환자 수 (%)'. This is a result of 'revisit_cnt' divided by 'visit_cnt'.

답변예시:
1. 최근 3개월 동안인 2022년 4월, 5월, 6월의 '신규환자수/총환자수 비율(%)'은 순서대로 12.85%, 11.04%, 8.24%로 감소하는 추세를 보입니다. 이는 최근에 신규 환자의 수가 감소하고 있는 것을 나타냅니다.,
2. 2022년 3월에 '비급여/총매출 비율(%)'이 37.47%로, 이전 달인 2022년 2월에 비해 상승한 것을 알 수 있습니다. 이는 비급여 항목에서 발생한 매출이 증가하였음을 의미합니다.,
3. 2022년 1월의 '재진환자수/총환자수 비율(%)'은 87.83%로, 신규 환자 대비 재진 환자의 비율이 높은 것을 보여줍니다. 이는 한의원에 재방문하는 환자들이 많았음을 의미합니다.,
4. '총 매출'은 2022년 3월까지 증가하였으나, 이후에는 다소 감소하는 추세를 보이고 있습니다.,
5. 처음 1~3번째 행인 2019년 1월, 2월, 3월에 비해, 최근 3개월 동안 '환자 수'가 감소하였습니다.,
6. 최근 3개월간 '신규 환자수'가 가장 높았던 달은 2022년 5월로, 이 달의 신규 환자수는 598명입니다.,
7. 2022년 6월에는 '신규환자수/총환자수 비율(%)'이 8.24%로 가장 낮았습니다. 이는 해당 달에 신규 환자의 수가 크게 감소하였음을 의미합니다.

타겟 데이터테이블:
월별 날짜,비급여 총매출,총 매출,신규 환자수,환자 수,자보매출,공단청구금,본인부담금,재진 환자수,신규환자수/총환자수 비율(%),재진환자수/총환자수 비율(%),비급여/총매출 비율(%)
2019-01-01,19539700.0,50102420.0,104.0,914.0,5889470.0,18344860.0,6328390.0,810.0,11.37855579868709,88.62144420131291,38.999513396758076
2019-02-01,21512400.0,49019840.0,69.0,793.0,6914120.0,15178630.0,5414690.0,724.0,8.701134930643127,91.29886506935688,43.88508816022247
2019-03-01,31681600.0,58688860.0,103.0,860.0,3993100.0,17213140.0,5801020.0,757.0,11.976744186046512,88.0232558139535,53.982306011737144
2020-09-01,22408050.0,62871700.0,77.0,1023.0,8598540.0,22313490.0,9551620.0,946.0,7.526881720430108,92.47311827956989,35.6409163423289
2020-10-01,25480700.0,64600540.0,68.0,1020.0,7467980.0,22281320.0,9370540.0,952.0,6.666666666666667,93.33333333333333,39.4434783362492
2020-11-01,25151300.0,70703390.0,87.0,1131.0,11734940.0,23590100.0,10227050.0,1044.0,7.6923076923076925,92.3076923076923,35.57297606239248
2020-12-01,16310400.0,49231950.0,85.0,785.0,8477880.0,16807920.0,7635750.0,700.0,10.828025477707007,89.171974522293,33.12970540472193
2021-01-01,15008400.0,55931230.0,97.0,892.0,11928360.0,19236940.0,9757530.0,795.0,10.874439461883407,89.12556053811659,26.83366698711972
2021-02-01,22614000.0,65190650.0,105.0,989.0,13385620.0,19393590.0,9797440.0,884.0,10.616784630940344,89.38321536905966,34.68902365599975


- 최근 3개월과 처음 1~3번째 행의 기간이 중요하다. 이 두 기간동안의 피드백질문이 중요하다.
- "Columns explanation"은 '타겟 데이터테이블'의 각각 컬럼들에 대한 설명이다.
- "특이점"은 "타겟 데이터테이블"을 분석한 특이점들이다. 
- 이 "특이점"들을 참고하여 이를 기준으로 "타겟 데이터테이블"을 분석하라.
- "타겟 데이터테이블"의 아래로 갈수록 최근 날짜의 데이터이다.
- "참고"에서 질문생성 답변 양식과 말투를 참고하되, "타겟 데이터테이블"에 없는 내용은 절대 언급하지마.
- 사실적인 질문보다는 추론적인 피드백 질문을 해줘.
- 피드백질문을 창의적으로 생성해줘


참고 :
'이탈률과 삼진율 개선과 평환이 회복세입니다. 부도율은 아직 개선이 필요할 것 같은데요. 예약 리마인드 연락에 대한 정책은 어떻게 셋팅되어 있나요?',
 '복잡추나 권유 시 어떤 커뮤니케이션 전략이 있었나요?',
 '이번달 다이어트 매출 목표 얼마셨을까요? 다이어트 이벤트 계획했던 것에 비해 어느정도 달성하셨다고 보시는지 궁금합니다. 다이어트 DM 보내시고 반응은 어땠는지도 공유 부탁드립니다.',
 '이번달 총환자수 최고기록을 세웠습니다. 1번에서 말씀드린 총매출, 비급여매출 경향성이 신규환자 그래프와도 맞아 떨어지는데요. 초진 상담에서 비급여 결제율이 높은 편일까요? 초진유입 개선책도 필요할 것 같습니다.',
 '신규환자수 156명 중 소개환자 77명으로 50% 비중을 차지합니다. 소개환자 관리 어떻게 하고 계신지 노하우 소개 부탁드립니다.'
특이점:
1. 최근 3개월에 해당하는 2021년 2월, 1월, 2020년 12월에 비해 첫 3개월인 2019년 1월, 2월, 3월과 비교할 때, '신규환자수/총환자수 비율(%)'이 감소하였습니다. 특히, 최근 3개월 동안 이 비율이 10% 이하로 떨어진 것을 볼 수 있습니다.
2. 마찬가지로, 최근 3개월간 '비급여/총매출 비율(%)'이 첫 3개월에 비해 상승하였습니다. 이는 비급여 상품의 판매가 증가하였음을 나타냅니다.
3. '재진환자수/총환자수 비율(%)'을 보면, 2019년 1월부터 일관적으로 이 비율이 높은 것을 확인할 수 있습니다. 그 중에서도, 2020년 10월에는 이 비율이 비교적 높게 나타났습니다.
4. '총 매출'을 살펴보면, 2019년 1월부터 2020년 11월까지는 매출이 상승하는 추세를 보였으나, 2020년 12월 이후로는 비교적 감소하는 추세를 보이고 있습니다.
5. 첫 3개월과 최근 3개월을 비교해볼 때, '환자 수'가 증가한 것으로 나타났습니다. 특히, 2021년 2월에는 비교적 많은 환자 수를 기록하였습니다.
6. '신규 환자수'에 대한 데이터를 보면, 2021년 2월에 비교적 많은 신규 환자를 받았음을 알 수 있습니다.
7. 또한, '비급여/총매출 비율(%)'은 2021년 2월에 비교적 높은 값을 보였습니다. 이는 비급여 상품의 매출이 총 매출에 큰 비중을 차지하였음을 의미합니다.
"""

# %%
#- "가장"이라는 극단적인 단어 표현 대신, "비교적 크게" 혹은 "비교적 많이"처럼 순화적인 표현을 사용해줘.

"Target data table" is data for a particular medical clinic.
Make 7 comprehensive analysis of the columns of "Target data table", base on some characteristics and overall trends of the data.
Then based on this analysis, make 7 creative questions that can give feedback for the develepment of management to this medical clinic, including specific dates of the data.
Never mention any informations that are not given by "Target data table"

These are some rules that you should strictly follow:
- The last 3 months datas are important.
- Your analysis should be only based on "Target data table".
- When you make your comprehensive anlysis, including specific dates of the data.
- In "Target data table", the lower the row is, the more recent the data is.
- Don't forget to not mention the date that is not in "Target data table".
- "Columns explanation" is explanation of each columns in "Target data table".
- Remember, make 7 comprehensive analysis, and 7 questions for the feedback.
- Try to make comprehensive(reason-asking) questions, rather than obvious fact asking ones.
- Make your answer in Korean.

Columns explanation:
- 'biz_dt' means '날짜'.
- 'total_pay' means '총 매출'. It's total sales of medical clinic for a month. It's the sum of '비급여 총매출', '자보매출', '공단청구금', '본인부담금', '입원실 매출', '기타매출'.
- 'nonbenefit_total_pay' means '비급여 총매출'. This sales are paid by patient 100%.It is important for medical clinics to induce sales of these items to increase total sales.
- 'carinsur_pay' means '자보매출'. These sales are sales that auto insurance companies provide medical expenses for patients who come to medical clinics due to traffic accidents.
- 'nhis_pay' means '공단청구금'. These sales are paid by the Health Care Corporation, etc., which patients who visited the medical clinic joined.
- 'co_pay' means '본인부담금'. These are the remaining expenses after paying a portion of the patient's medical expenses from the corporation or insurance. It's the sales that the patient pays directly to the hospital.
- 'room_pay' means '입원실 매출'. These sales are paid by inpatients during their hospitalization period.
- 'etc_pay' means '기타매출'. These are sales that occurred outside of medical treatment.
- 'visit_cnt' means '환자 수'. This indicates the total number of patients who visited the hospital for a month.
- 'fstvisit_cnt' means '신규 환자수'. This indicates the number of patients who visited the hospital for the first time.
- 'revisit_cnt' means '재진 환자수'. This indicates the number of patients for a month, who visitied the hospital before
- 'fstvisit_cnt/visit_cnt (%)' means '신규 환자수/환자수 (%)'. This is a result of 'fstvisit_cnt' divided by 'visit_cnt'.
- 'nonbenefit_total_pay/total_pay (%)' means '비급여 총매출/총 매출 (%)'. This is a result of 'nonbenefit_total_pay' divided by 'total_pay'.
- 'revisit_cnt/visit_cnt (%)' means '재진 환자수/환자 수 (%)'. This is a result of 'revisit_cnt' divided by 'visit_cnt'.


Target data table:
biz_dt,nonbenefit_total_pay,total_pay,fstvisit_cnt,visit_cnt,carinsur_pay,nhis_pay,co_pay,revisit_cnt,fstvisit_cnt/visit_cnt (%),revisit_cnt/visit_cnt (%),nonbenefit_total_pay/total_pay (%)
2019-01-01,19539700.0,50102420.0,104.0,914.0,5889470.0,18344860.0,6328390.0,810.0,11.37855579868709,88.62144420131291,38.999513396758076
2019-02-01,21512400.0,49019840.0,69.0,793.0,6914120.0,15178630.0,5414690.0,724.0,8.701134930643127,91.29886506935688,43.88508816022247
2019-03-01,31681600.0,58688860.0,103.0,860.0,3993100.0,17213140.0,5801020.0,757.0,11.976744186046512,88.0232558139535,53.982306011737144
2020-09-01,22408050.0,62871700.0,77.0,1023.0,8598540.0,22313490.0,9551620.0,946.0,7.526881720430108,92.47311827956989,35.6409163423289
2020-10-01,25480700.0,64600540.0,68.0,1020.0,7467980.0,22281320.0,9370540.0,952.0,6.666666666666667,93.33333333333333,39.4434783362492
2020-11-01,25151300.0,70703390.0,87.0,1131.0,11734940.0,23590100.0,10227050.0,1044.0,7.6923076923076925,92.3076923076923,35.57297606239248
2020-12-01,16310400.0,49231950.0,85.0,785.0,8477880.0,16807920.0,7635750.0,700.0,10.828025477707007,89.171974522293,33.12970540472193
2021-01-01,15008400.0,55931230.0,97.0,892.0,11928360.0,19236940.0,9757530.0,795.0,10.874439461883407,89.12556053811659,26.83366698711972
2021-02-01,22614000.0,65190650.0,105.0,989.0,13385620.0,19393590.0,9797440.0,884.0,10.616784630940344,89.38321536905966,34.68902365599975

# %%
Total Revenue Fluctuation: The medical clinic's total monthly revenue varies significantly across the data period, with the lowest being around 49,019,840 in February 2019 and the highest at 72,866,600 in December 2019. This suggests that the clinic's total income is not steady but fluctuates, potentially due to changes in patient volume or the range of services offered.

Reliance on Non-Benefit Pay: There is a notable increase in the percentage of nonbenefit_total_pay over time, which is the payment completely borne by patients. It started from 38.99% in January 2019 and saw a significant increase up to 53.98% in March 2019, which gradually fluctuates and reaches 39.10% in July 2020.

Patient Visit Trend: There is an increasing trend in the total number of patients (visit_cnt) visiting the clinic over time, starting at 914 in January 2019 and reaching a peak at 1234 in August 2019. There are slight declines and increases afterwards, but it maintains above 1000 after July 2019.

First-Time Patients Percentage: The percentage of new patients (fstvisit_cnt/visit_cnt (%)) fluctuates between 6.66% to 11.97% throughout the observed period. It is an important metric indicating the clinic's ability to attract new patients, with the peak observed in March 2019.

Revisit Rates: The revisit rates (revisit_cnt/visit_cnt (%)) are consistently high, ranging from 88.62% to 93.33%. This indicates that the clinic has a high retention rate and is able to effectively provide satisfactory services, encouraging patients to return for further treatment.

Insurance and Other Payments: The clinic receives a substantial part of its revenue from insurance companies (carinsur_pay, nhis_pay) and patient co-payments (co_pay). These revenue streams appear to be stable, but a deeper investigation could reveal any underlying trends or seasonal effects.

Recent Three Months Trend: Focusing on the last three months data (November 2020 - January 2021), we can see a rise in the total revenue from 49,231,950 to 65,190,650. The percentage of nonbenefit_total_pay also increased from 33.13% to 34.69% during the same period, suggesting a growing reliance on patient-borne costs.

Questions for Feedback:

What strategies could be implemented to stabilize the fluctuating total revenue, ensuring a more predictable and sustainable income?
Given the increasing reliance on nonbenefit_total_pay, are there plans to expand more non-benefit services or increase the prices of existing ones?
With the increasing trend in patient visits, does the clinic have enough capacity to maintain the quality of services provided to patients?
What marketing or patient outreach initiatives could be implemented to increase the percentage of new patients visiting the clinic?
How can the clinic further enhance its services to maintain the high revisit rates, considering the changing medical needs and expectations of patients?
Are there any ongoing negotiations or plans to increase the clinic's revenue from insurance companies and co-payments?
Based on the upward trend in total revenue and nonbenefit_total_pay in the last three months, does the clinic anticipate this trend to continue, and what measures are in place to ensure this?

# %%
"타겟 데이터테이블"은 특정 한의원에 대한 데이터이다.
"타겟 데이터테이블"의 컬럼들을 복합적으로 분석해서 큰 특이점 또는 추세를 다양하게 7가지 알려줘.
그리고 이 특이점과 추세들를 기준으로 한의원 경영을 위한 창의적인 피드백 질문들을 7개 생성해줘.
"타겟 데이터테이블"에 없는 날짜나 내용은 절대 언급하지마.

- "타겟 데이터테이블"의 아래로 갈수록 최근 날짜의 데이터이다.
- "타겟 데이터테이블"의 가장 마지막 행이 가장 최근 달의 데이터이다.
- 가장 최근 달과 그 이전달의 데이터를 비교하는 질문을 2개 만들어라.
- 가장 최근 달과 그 이전 3개월을 비교하는 질문을 2개 만들어라.
- 가장 최근 달과 그 이전 6개월을 비교하는 질문을 2개 만들어라.
- 오직 '타겟 데이터테이블'에 있는 내용으로만 분석해야한다.
- "Columns explanation"은 '타겟 데이터테이블'의 각각 컬럼들에 대한 설명이다.
- "가장"이라는 극단적인 단어 표현 대신, "비교적 크게" 혹은 "비교적 많이"처럼 순화적인 표현을 사용해줘.
- 특이점과 피드백 질문을 생성할 때, 구체적인 날짜나 기간도 언급해줘.
- "타겟 데이터테이블"의 "biz_dt"컬럼에 없는 날짜는 절대 언급하지마.
- 사실적인 질문보다는 추론적인 피드백 질문을 해줘.
- 피드백질문을 창의적으로 생성해줘
- 특이점 하나, 그에 대한 피드백 질문 하나 이런 방식으로 생성해줘.

Columns explanation:
- 'biz_dt' means '날짜'.
- 'total_pay' means '총 매출'. It's total sales of medical clinic for a month. It's the sum of '비급여 총매출', '자보매출', '공단청구금', '본인부담금', '입원실 매출', '기타매출'.
- 'nonbenefit_total_pay' means '비급여 총매출'. This sales are paid by patient 100%.It is important for medical clinics to induce sales of these items to increase total sales.
- 'carinsur_pay' means '자보매출'. These sales are sales that auto insurance companies provide medical expenses for patients who come to medical clinics due to traffic accidents.
- 'nhis_pay' means '공단청구금'. These sales are paid by the Health Care Corporation, etc., which patients who visited the medical clinic joined.
- 'co_pay' means '본인부담금'. These are the remaining expenses after paying a portion of the patient's medical expenses from the corporation or insurance. It's the sales that the patient pays directly to the hospital.
- 'room_pay' means '입원실 매출'. These sales are paid by inpatients during their hospitalization period.
- 'etc_pay' means '기타매출'. These are sales that occurred outside of medical treatment.
- 'visit_cnt' means '환자 수'. This indicates the total number of patients who visited the hospital for a month.
- 'fstvisit_cnt' means '신규 환자수'. This indicates the number of patients who visited the hospital for the first time.
- 'revisit_cnt' means '재진 환자수'. This indicates the number of patients for a month, who visitied the hospital before
- 'fstvisit_cnt/visit_cnt (%)' means '신규 환자수/환자수 (%)'. This is a result of 'fstvisit_cnt' divided by 'visit_cnt'.
- 'nonbenefit_total_pay/total_pay (%)' means '비급여 총매출/총 매출 (%)'. This is a result of 'nonbenefit_total_pay' divided by 'total_pay'.
- 'revisit_cnt/visit_cnt (%)' means '재진 환자수/환자 수 (%)'. This is a result of 'revisit_cnt' divided by 'visit_cnt'.

타겟 데이터테이블:
biz_dt,nonbenefit_total_pay,total_pay,fstvisit_cnt,visit_cnt,carinsur_pay,nhis_pay,co_pay,revisit_cnt,fstvisit_cnt/visit_cnt (%),revisit_cnt/visit_cnt (%),nonbenefit_total_pay/total_pay (%)
2019-01-01,19539700.0,50102420.0,104.0,914.0,5889470.0,18344860.0,6328390.0,810.0,11.37855579868709,88.62144420131291,38.999513396758076
2019-02-01,21512400.0,49019840.0,69.0,793.0,6914120.0,15178630.0,5414690.0,724.0,8.701134930643127,91.29886506935688,43.88508816022247
2019-03-01,31681600.0,58688860.0,103.0,860.0,3993100.0,17213140.0,5801020.0,757.0,11.976744186046512,88.0232558139535,53.982306011737144
2020-09-01,22408050.0,62871700.0,77.0,1023.0,8598540.0,22313490.0,9551620.0,946.0,7.526881720430108,92.47311827956989,35.6409163423289
2020-10-01,25480700.0,64600540.0,68.0,1020.0,7467980.0,22281320.0,9370540.0,952.0,6.666666666666667,93.33333333333333,39.4434783362492
2020-11-01,25151300.0,70703390.0,87.0,1131.0,11734940.0,23590100.0,10227050.0,1044.0,7.6923076923076925,92.3076923076923,35.57297606239248
2020-12-01,16310400.0,49231950.0,85.0,785.0,8477880.0,16807920.0,7635750.0,700.0,10.828025477707007,89.171974522293,33.12970540472193
2021-01-01,15008400.0,55931230.0,97.0,892.0,11928360.0,19236940.0,9757530.0,795.0,10.874439461883407,89.12556053811659,26.83366698711972
2021-02-01,22614000.0,65190650.0,105.0,989.0,13385620.0,19393590.0,9797440.0,884.0,10.616784630940344,89.38321536905966,34.68902365599975

# %%
특이점: 2020년 12월에 '비급여 총매출'이 그 전달들에 비해 비교적 크게 감소하였다. 이는 전체 '총 매출'도 감소하였음을 의미한다.
피드백 질문: 2020년 12월에는 '비급여 총매출'이 감소한 이유가 무엇인지 파악했나요? 비급여 서비스에 대한 환자들의 관심이 감소한 것인지, 아니면 다른 외부 요인이 작용한 것인지 추론해보았나요?

특이점: '재진 환자수'와 '환자 수'의 비율이 대체로 비교적 많이 유지되고 있다. 이는 재진 환자가 대부분을 차지하고 있다는 것을 나타낸다.
피드백 질문: '재진 환자'가 주로 이루는 병원 경영 구조를 고려하면, 이들 재진 환자들이 계속해서 병원을 찾는 이유는 무엇이라고 생각하나요? 재진 환자들의 경험을 개선하기 위한 방법을 고려해보았나요?

특이점: 2020년 9월부터 2021년 2월까지 '자보매출'이 비교적 크게 증가하였다.
피드백 질문: '자보매출'의 증가는 어떠한 전략의 결과로 보여집니까? 또한, 이 증가 추세를 유지하는 방법은 무엇일까요?

특이점: '신규 환자수'와 '환자 수'의 비율은 대체로 일정하게 유지되는 반면, 2020년 11월에 이 비율이 비교적 많이 증가하였다.
피드백 질문: 2020년 11월에 '신규 환자수'가 증가한 이유를 파악하였나요? 특별히 그 달에 신규 환자를 유치하는데 효과적인 마케팅 전략이 있었나요?

특이점: 2020년 12월부터 2021년 2월까지 '공단청구금'이 비교적 크게 감소하였다.
피드백 질문: '공단청구금' 감소에 대한 원인을 분석해보았나요? 이로 인한 병원의 금융 상태에는 어떠한 변화가 있었나요?

특이점: '본인부담금'이 전반적으로 일정한 비율로 유지되고 있다. 그러나 2020년 9월부터 2021년 2월까지 이 비율이 비교적 크게 증가하였다.
피드백 질문: '본인부담금' 증가의 원인이 무엇인지 추론해보았나요? 이 증가가 환자의 의료 서비스 이용에 부정적인 영향을 미치지 않았나요?

특이점: '비급여 총매출'과 '총 매출'의 비율이 대체로 증가하는 추세를 보이고 있다. 이는 비급여 서비스의 중요성이 증가하고 있음을 나타낸다.
피드백 질문: 비급여 서비스를 더욱 강화하고 개발하기 위한 전략이 무엇인가요? 특히, 이 서비스를 환자들에게 더욱 잘 알리고, 이를 이용하도록 유도하는 방법은 무엇인가요?

# %%
import pandas as pd

df = pd.read_csv('/home/fastcampus/Seokjun/csv_8/df_gangnammyungin_eng.csv')
df
# Out:
#        biz_dt  nonbenefit_total_pay   total_pay  fstvisit_cnt  visit_cnt
# 0  2019-01-01            19539700.0  50102420.0         104.0      914.0  \
# 1  2019-02-01            21512400.0  49019840.0          69.0      793.0
# 2  2019-03-01            31681600.0  58688860.0         103.0      860.0
# 3  2020-09-01            22408050.0  62871700.0          77.0     1023.0
# 4  2020-10-01            25480700.0  64600540.0          68.0     1020.0
# 5  2020-11-01            25151300.0  70703390.0          87.0     1131.0
# 6  2020-12-01            16310400.0  49231950.0          85.0      785.0
# 7  2021-01-01            15008400.0  55931230.0          97.0      892.0
# 8  2021-02-01            22614000.0  65190650.0         105.0      989.0
#
#    carinsur_pay    nhis_pay      co_pay  revisit_cnt
# 0     5889470.0  18344860.0   6328390.0        810.0  \
# 1     6914120.0  15178630.0   5414690.0        724.0
# 2     3993100.0  17213140.0   5801020.0        757.0
# ...
