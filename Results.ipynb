# %% [markdown]
# ## 1. GPT EN

# %%
# 질문뽑아보기 En
def gpt_answer(msg):

    openai.api_key="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"

    answer=[]

    system_prompt ="""You are a helpful assistant designed to make feedback questions
                    from given datas.
                        Make these in Korean.
                        User will send string type table data to you and you have to
                    analyze that table in oreder to give feedback questions
                        Questions must contain complex concept of datas.
                        Do not ask factual questions about table, but rather inference one.
                        Questions must mention a specific date.
                        
                        Instructions:
                        - 'biz_dt' means '날짜'
                        - 'nonbenefit_total_pay' means '비급여 총매출'
                        - 'total_pay' means '총 매출'
                        - 'visit_cnt' means '환자 수'
                        - 'fstvisit_cnt' means '신규 환자수'
                        - 'carinsur_pay' means '자보매출'
                        - 'nhis_pay' means '공단청구금'

                    
                    """

    completion = openai.ChatCompletion.create(
        model = "gpt-3.5-turbo",
        messages=[{"role": "system", "content": system_prompt},
                    {"role": "user", "content": f"""This is the table. {msg}
                                            Please make five Questions"""}]
        )

    for choice in completion.choices:
        print(choice['message']['content'])
        answer.append(choice['message']['content'].strip())

    return answer

# %%
def gpt_final(msg, qs):
   
    conversation = [
        {
            "role": "system",
            "content": """You are a helpful assistant designed to make feedback questions
                        from given datas.
                            Make these in Korean.
                            User will send string type table data to you and you have to
                        analyze that table in oreder to give feedback questions
                            Questions must contain complex concept of datas.
                            Do not ask factual questions about table, but rather inference one.
                            Questions must mention a specific date.
                            
                            Instructions:
                            - 'biz_dt' means '날짜'
                            - 'nonbenefit_total_pay' means '비급여 총매출'
                            - 'total_pay' means '총 매출'
                            - 'visit_cnt' means '환자 수'
                            - 'fstvisit_cnt' means '신규 환자수'
                            - 'carinsur_pay' means '자보매출'
                            - 'nhis_pay' means '공단청구금'"""
        },
        {
            "role": "user",
            "content": f"""
            아래 테이블 데이터를 종합하여 큰 특이점을 기준으로 경영을 위한 창의적인 피드백 질문들을 5개 생성해줘.
            테이블에 없는 이야기는 하지 말아줘. 
            생성 예시 : {qs}
            데이터 테이블 :
            {msg}
            """
        }
    ]

    import openai
    openai.api_key="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"

    response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=conversation
    )

    for choice in response.choices:
        print(choice['message']['content'])

# %% [markdown]
# - 날질문
#
#   1. 지난해 9월과 2020년 2월의 비급여 총매출은 각각 얼마였나요? 이 기간 동안 비급여 총매출은 어떠한 추이를 보였나요?
#   2. 2018년 10월부터 2019년 1월까지의 첫방환자수와 재방환자수는 각각 어떻게 나왔나요? 이 기간 동안 방문한 전체 환자 수는 몇 명이었나요?
#   3. 전체 공단청구금 중에서 2019년 3월에는 어느 정도 비율을 차지했나요? 지난해 12월과 2020년 1월에도 비슷한 비율을 보였을까요?
#   4. 신규 환자 수가 가장 많은 월과 가장 적은 월은 각각 언제인가요? 이들 월 간 방문 환자의 차이는 어떠한가요?
#   5. 2018년 12월부터 2020년 1월까지의 총 매출 추이는 어떻게 나타나고 있나요? 또한, 이 기간 동안 특히 매출이 높았던 달과 그 이유는 무엇일까요?
#
# - 유사도 질문
#  '대진원장님 진료 모니터링 어떻게 하실까요? 지표 관리 어떻게 설정하셨는지 여쭤봅니다.',
#  '재초진 환자수 상승 주요인이 뭘까요? 환자 회귀현상에 대해 어떻게 보고 계신지요?',
#  '녹용한약과 다이어트 한약관련 고도화 전략이 필요해보입니다. 계획이 있으실까요? 구상하신 실천안을 말씀 부탁드립니다.',
#  '원장님 지난 6월 직원 교육을 통해 환자 커뮤니케이션 개선 말씀주셨습니다. 7월 결과가 좋았고 8월에 주춤했지만 9월 다시 반등했습니다. 어떤 요인의 결과로 보실까요?',
#  '데스크 예약 접수율 하락된 요인은 무엇일까요?'
#
# - 최종 질문
#   1. 2019년 3월에 방문 수가 증가한 이유는 무엇일까요?
#   2. 평균 환자 수 대비 신규 환자 수의 변화가 큰 달이 있는데, 그 달에는 어떠한 변화가 있었을까요?
#   3. 2018년 10월과 2018년 11월 비급여 총 매출이 크게 감소한 이유를 추측해보세요.
#   4. 2019년 7월 공단청구금이 크게 감소했는데, 이는 어떤 이유에서 발생한 것으로 보이나요?
#   5. 자보매출 비중이 높아지는 것은 어떤 요인으로 인해 발생한 것으로 보이나요?

# %% [markdown]
# #### :: 평가
# - 날질문의 퀄리티가 낮다. -> 계속해서 사실을 묻는 질문 위주.
# - 최종질문에서는 이유나 변화 요인등을 추론하게 만드는 질문 -> 사실적 질문이 아닌 추론적 질문으로 변화
# - 거짓된 정보들이 꽤나 많다.

# %% [markdown]
# ## 2. GPT KR (final은 그대로)

# %%
# 질문뽑아보기 KR
def gpt_answer(msg):

    openai.api_key="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"

    answer=[]

    system_prompt ="""너는 주어진 정보를 보고 경영체의 발전을 위해 피드백 해주는 전문가야.
                     다음에 주어질 테이블 데이터를 종합하여 특이점과 변동하는 값들에 기반하여 
                     이 병원을 위한 피드백 질문 5가지를 생성해줘. 구체적인 날짜를 언급해줘.
                        
                        Instructions:
                        - 'biz_dt' means '날짜'
                        - 'nonbenefit_total_pay' means '비급여 총매출'
                        - 'total_pay' means '총 매출'
                        - 'visit_cnt' means '환자 수'
                        - 'fstvisit_cnt' means '신규 환자수'
                        - 'carinsur_pay' means '자보매출'
                        - 'nhis_pay' means '공단청구금'

                    
                    """

    completion = openai.ChatCompletion.create(
        model = "gpt-3.5-turbo",
        messages=[{"role": "system", "content": system_prompt},
                    {"role": "user", "content": f"""This is the table. {msg}"""}]
        )

    for choice in completion.choices:
        print(choice['message']['content'])
        answer.append(choice['message']['content'].strip())

    return answer

# %%
def gpt_final(msg, qs):
   
    conversation = [
        {
            "role": "system",
            "content": """You are a helpful assistant designed to make feedback questions
                        from given datas.
                            Make these in Korean.
                            User will send string type table data to you and you have to
                        analyze that table in oreder to give feedback questions
                            Questions must contain complex concept of datas.
                            Do not ask factual questions about table, but rather inference one.
                            Questions must mention a specific date.
                            
                            Instructions:
                            - 'biz_dt' means '날짜'
                            - 'nonbenefit_total_pay' means '비급여 총매출'
                            - 'total_pay' means '총 매출'
                            - 'visit_cnt' means '환자 수'
                            - 'fstvisit_cnt' means '신규 환자수'
                            - 'carinsur_pay' means '자보매출'
                            - 'nhis_pay' means '공단청구금'"""
        },
        {
            "role": "user",
            "content": f"""
            아래 테이블 데이터를 종합하여 큰 특이점을 기준으로 경영을 위한 창의적인 피드백 질문들을 5개 생성해줘.
            테이블에 없는 이야기는 하지 말아줘. 
            생성 예시 : {qs}
            데이터 테이블 :
            {msg}
            """
        }
    ]

    import openai
    openai.api_key="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"

    response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=conversation
    )

    for choice in response.choices:
        print(choice['message']['content'])

# %% [markdown]
# - 날질문
#   1. 2018년 10월 부터 2019년 05월까지 총 매출이 크게 상승한 것으로 나타나고 있습니다. 이에 대하여 총 매출 상승 원인과 유발한 행사나 프로모션 등이 있는지 물어보시기를 권장합니다.
#   2. 2019년 06월부터 2019년 08월 사이 비급여 총 매출과 총 매출이 감소하는 것으로 나타나고 있습니다. 원인 파악 후 개선 방안 모색을 위해 어떠한 조치를 취했는지 궁금합니다.
#   3. 자보매출에서 2019년 09월에 급격한 상승이 나타나고 있습니다. 이에 대하여 해당 월에 자보매출이 급증한 이유와 그에 따른 추가적인 계획이 있는지 물어보시기를 권장합니다.
#   4. 환자 수가 어떤 경향을 보이고 있는지 파악하고 있으며, 2018년 12월 부터 2019년 01월 사이 환자 수가 상승했다가, 다시 하락한 것으로 보입니다. 해당 월에 환자 수가 급변한 원인과 대응방안이 있는지 물어보시기를 권장합니다.
#   5. 2020년 01월부터 2020년 02월까지 비급여 총 매출이 감소하고 있는 것으로 나타났습니다. 이에 해당 기간에 마케팅 캠페인이나 행사, 프로모션 등 특별한 홍보 활동이 있는지, 그리고 이에 대한 효과는 어떠한지 물어보시기를 권장합니다.
#
# - 유사도 질문
#     '예약 내원 환자 비율이 낮은편이고 통증 프로그램 성공률과 소개 환자 비율이 이어지지 않는 다는 느낌이 있는데, 현재 인터넷 초진 > 통증 프로그램 결제 패턴이 주된 흐름으로 보입니다. 그렇다면 현재 전략을 고수 하시는 방향으로 가실건가요? 아니면, 초진과 주요 매출 전략의 변화가 있을까요? 현재는 결제를 3개월에서 1개월로 전환한 것이 전략 변경으로 보입니다.'
#
#     '비급여 매출의 큰 반등에 녹용한약이 기여했습니다. 어떤 요인이 작용한 결과일까요? 결과를 통한 원장님의 인사이트와 장기적 매출 안정화를 위한 전략 말씀주세요.'
#
#     '예약 내원 환자 비율이 낮은편이고 통증 프로그램 성공률과 소개 환자 비율이 이어지지 않는 다는 느낌이 있는데, 현재 인터넷 초진 > 통증 프로그램 결제 패턴이 주된 흐름으로 보입니다. 그렇다면 현재 전략을 고수 하시는 방향으로 가실건가요? 아니면, 초진과 주요 매출 전략의 변화가 있을까요? 현재는 결제를 3개월에서 1개월로 전환한 것이 전략 변경으로 보입니다.'
#
#     '경옥고,공진단이 상시판매가 가능한 이유 무엇이라 생각하세요?'
#
#     '예약 내원 환자 비율이 낮은편이고 통증 프로그램 성공률과 소개 환자 비율이 이어지지 않는 다는 느낌이 있는데, 현재 인터넷 초진 > 통증 프로그램 결제 패턴이 주된 흐름으로 보입니다. 그렇다면 현재 전략을 고수 하시는 방향으로 가실건가요? 아니면, 초진과 주요 매출 전략의 변화가 있을까요? 현재는 결제를 3개월에서 1개월로 전환한 것이 전략 변경으로 보입니다.'
#
# - 최종 질문
#   1. 2018년 10월 총 매출이 큰 폭으로 증가했습니다. 이에 대해 어떤 대응을 계획하시나요?
#
#   2. 2019년 3월 공단청구금이 크게 증가하는 것으로 보입니다. 이는 어떤 이유에 기인한 것인가요?
#
#   3. 2019년 7월 환자수는 작년 동월 보다 감소한 것으로 보입니다. 이에 대해 어떤 대응이 필요할까요?
#
#   4. 2019년 9월 자보 매출이 예년에 비해 큰 폭으로 증가한 것으로 보입니다. 이는 어떤 요인에 기인한 것인가요?
#
#   5. 2019년 12월 비급여 총 매출이 줄어든 것으로 보입니다. 이는 어떤 이유에 기인한 것인가요? 이에 대한 대응 계획이 있을까요?

# %% [markdown]
# #### :: 평가
# - 날질문의 프롬프트가 바뀌니 더욱 이유에 초점이 되는 추론적 질문으로 변하였다 GOOD
# - 그러나 제 3자에게 질문하기를 권하는 형식의 말투가 걸린다.
# - 최종질문이 너무 단순해졌다. 최종질문 프롬프트의 변화가 필요해보인다.
# - 유사질문이 3개나 겹친다. 갯수를 2개로 늘려본다.

# %% [markdown]
# ## 3. GPT KR (final도 바꿔보자) (유사도 2개씩)

# %%
def gpt_answer(msg):

    openai.api_key="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"

    answer=[]

    system_prompt ="""너는 주어진 정보를 보고 경영체의 발전을 위해 피드백 해주는 전문가야.
                     다음에 주어질 테이블 데이터를 종합하여 특이점과 변동하는 값들에 기반하여 
                     이 병원을 위한 피드백 질문 5가지를 생성해줘. 구체적인 날짜를 언급해줘.
                        
                        Instructions:
                        - 'biz_dt' means '날짜'
                        - 'nonbenefit_total_pay' means '비급여 총매출'
                        - 'total_pay' means '총 매출'
                        - 'visit_cnt' means '환자 수'
                        - 'fstvisit_cnt' means '신규 환자수'
                        - 'carinsur_pay' means '자보매출'
                        - 'nhis_pay' means '공단청구금'

                    
                    """

    completion = openai.ChatCompletion.create(
        model = "gpt-3.5-turbo",
        messages=[{"role": "system", "content": system_prompt},
                    {"role": "user", "content": f"""This is the table. {msg}"""}]
        )

    for choice in completion.choices:
        print(choice['message']['content'])
        answer.append(choice['message']['content'].strip())

    return answer

# %%
def gpt_final(msg, qs):
   
    conversation = [
        {
            "role": "system",
            "content": """너는 주어진 정보를 보고 경영체의 발전을 위해 피드백 해주는 전문가야.
                     다음에 주어질 테이블 데이터를 종합하여 특이점과 변동하는 값들에 기반하여 
                     이 병원을 위한 피드백 질문 5가지를 생성해줘. 구체적인 날짜를 언급해줘.
                     너의 질문들의 형태는 주어지는 '생성 예시'를 참고해서 최대한 비슷하게 만들어줘.
                     질문은 한가지 영역에 관한 단순한 질문이 아닌, 모든 영역의 지표들을 종합적으로 고려해서 만들어줘.
                            
                            Instructions:
                            - 'biz_dt' means '날짜'
                            - 'nonbenefit_total_pay' means '비급여 총매출'
                            - 'total_pay' means '총 매출'
                            - 'visit_cnt' means '환자 수'
                            - 'fstvisit_cnt' means '신규 환자수'
                            - 'carinsur_pay' means '자보매출'
                            - 'nhis_pay' means '공단청구금'"""
        },
        {
            "role": "user",
            "content": f"""
            질문을 만들 때, 절대 테이블에 없는 이야기나, 테이블의 데이터와 일치하지 않는 정보는 언급하지 말아줘. 
            생성 예시 : {qs}
            데이터 테이블 :
            {msg}
            """
        }
    ]

    import openai
    openai.api_key="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"

    response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=conversation
    )

    for choice in response.choices:
        print(choice['message']['content'])

# %% [markdown]
# - 날질문
#   1. 2018년 10월 총 매출이 이전 달 대비 크게 증가한 이유는 무엇인가요?
#   2. 2018년 12월부터 2019년 1월로 넘어갈 때 비급여 총매출이 크게 증가한 이유가 무엇인가요?
#   3. 2019년 하반기에 환자 수가 크게 감소한 이유는 무엇인가요?
#   4. 2019년 5월, 6월에 자보매출이 갑자기 줄어든 이유가 무엇인가요?
#   5. 2020년 1월 신규 환자 수가 이전 달 대비 크게 감소한 이유가 무엇인가요?
#
# - 유사도 질문
#   '비급여 매출 2월 하락요인과 개선 전략은?'
#
#   '원장님 지난 6월 직원 교육을 통해 환자 커뮤니케이션 개선 말씀주셨습니다. 7월 결과가 좋았고 8월에 주춤했지만 9월 다시 반등했습니다. 어떤 요인의 결과로 보실까요?'
#
#   '비급여 매출 2월 하락요인과 개선 전략은?'
#
#   '주력 비급여 중 하나인 소아정신과의 매출 하락의 원인을 어떻게 평가하고 계신가요?'
#
#   '원장님 지난 6월 직원 교육을 통해 환자 커뮤니케이션 개선 말씀주셨습니다. 7월 결과가 좋았고 8월에 주춤했지만 9월 다시 반등했습니다. 어떤 요인의 결과로 보실까요?'
#
#   '이번달 신규환자수가 2배가량 늘었는데 지난달에 이어 환수관리를 위해 어떤 노력을 하셨는지 궁금합니다. 재진숫자가 1385>1939까지 급격하게 올라갔습니다.'
#
#   '비급여 매출 2월 하락요인과 개선 전략은?'
#
#   '비급여 매출 상승요인 무엇인가요?'
#
#   '원장님 지난 6월 직원 교육을 통해 환자 커뮤니케이션 개선 말씀주셨습니다. 7월 결과가 좋았고 8월에 주춤했지만 9월 다시 반등했습니다. 어떤 요인의 결과로 보실까요?'
#
#   '이번달 신규환자수가 2배가량 늘었는데 지난달에 이어 환수관리를 위해 어떤 노력을 하셨는지 궁금합니다. 재진숫자가 1385>1939까지 급격하게 올라갔습니다.'
#
# - 최종 질문
#   1. 2020년 2월 비급여 매출이 지난달 대비 큰 상승을 보였는데, 이는 어떤 요인으로 인한 것인가요?
#   2. 지난 1년간 매출 증감의 가장 큰 원인은 무엇인가요? 이에 대한 대처 방안이 필요하다면 어떤 것이 있을까요?
#   3. 최근 자보매출의 비중이 상승하고 있습니다. 이에 대한 대응책은 무엇이 필요할까요?
#   4. 환자 수는 안정적으로 증가하고 있지만, 신규 환자와 재진 환자의 수가 큰 차이를 보이고 있습니다. 어떤 방식으로 신규 환자를 유치하고 재진 환자를 유지할 수 있을까요?
#   5. 공단청구금은 지속적인 상승세를 보이고 있는데, 이는 어떤 이유로 인한 것인가요? 해당 문제에 대한 대응책이 필요할까요?

# %% [markdown]
# #### :: 평가
# - 날질문이 왜 또 조금 아쉽지....? 특이점만 찝어서 질문하는데 맘에 들지는 않아서 문제다.
# - 유사도는 2개씩 하는게 좋아보인다. 중복이 심하다.
# - 사실정확도가 의심된다. 당장의 질문으로는 좋아보이나 정확도가 떨어지면 의미가 없다.

# %% [markdown]
# ## 4. fewshot (경창한의원 1개를 예시로)

# %%
def gpt_answer(msg):

    openai.api_key="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"

    answer=[]

    ex_df = pd.read_csv('/home/fastcampus/Gasan/codes/경창예시.csv')

    system_prompt ="""너는 주어진 정보를 보고 경영체의 발전을 위해 피드백 해주는 전문가야.
                     다음에 주어질 테이블 데이터를 종합하여 특이점과 변동하는 값들에 기반하여 
                     이 병원을 위한 피드백 질문 5가지를 생성해줘. 구체적인 날짜를 언급해줘.
                        
                        Instructions:
                        - 'biz_dt' means '날짜'
                        - 'nonbenefit_total_pay' means '비급여 총매출'
                        - 'total_pay' means '총 매출'
                        - 'visit_cnt' means '환자 수'
                        - 'fstvisit_cnt' means '신규 환자수'
                        - 'carinsur_pay' means '자보매출'
                        - 'nhis_pay' means '공단청구금'
                     """

    completion = openai.ChatCompletion.create(
        model = "gpt-3.5-turbo",
        messages=[{"role": "system", "content": system_prompt},
                 {"role": "user", "content": f"""{ex_df}"""},
                 {"role": "assistant", "content":f"""
                   1. 최근 3개월간 비급여 매출이 총 매출 대비 어느정도의 비중을 차지하고 있나요?' 이에 따른 전략을 어떻게 세워야할까요?
                   2. 최근 6개월간 총 환자수 대비 신규환자수 비중이 높아지고 있습니다. 새로운 마케팅전략을 사용하고 계시나요? 어떤 요인이 큰 작용을 하였나요?
                   3. 2020년 4월 기점으로 비급여 매출 진폭이 1달 간격으로 큰데, 원인이 뭐라고 생각하시는지요? 이를 위한 안정화 전략은 무엇으로 보고 계신지요?
                   4. 환자 재내원을 위한 원내 정책 어떤 것들 있으신가요? 준비된 시스템에 대한 서술 부탁드립니다.
                   5. 2020년 4월 비급여 매출이 가장 높네요. 한약 매출 최초,재결제 성과 노하우 상세한 말씀 부탁드립니다.
                    """},
                   {"role": "user", "content":f"""{msg}"""}]
    )

    for choice in completion.choices:
        print(choice['message']['content'])
        answer.append(choice['message']['content'].strip())

    return answer

# %%
def gpt_final(msg, qs):
    
    ex_df = pd.read_csv('/home/fastcampus/Gasan/codes/경창예시.csv')

    conversation = [
        {
            "role": "system",
            "content": """너는 주어진 정보를 보고 경영체의 발전을 위해 피드백 해주는 전문가야.
                     다음에 주어질 테이블 데이터를 종합하여 특이점과 변동하는 값들에 기반하여 
                     이 병원을 위한 피드백 질문 5가지를 생성해줘. 구체적인 날짜를 언급해줘.
                     너의 질문들의 형태는 주어지는 '생성 예시'의 말투와 비슷하게 추론적인 질문들을 만들어줘.
                     질문은 한가지 영역에 관한 단순한 질문이 아닌, 모든 영역의 지표들을 종합적으로 고려해서 만들어줘.
                            
                            Instructions:
                            - 'biz_dt' means '날짜'
                            - 'nonbenefit_total_pay' means '비급여 총매출'
                            - 'total_pay' means '총 매출'
                            - 'visit_cnt' means '환자 수'
                            - 'fstvisit_cnt' means '신규 환자수'
                            - 'carinsur_pay' means '자보매출'
                            - 'nhis_pay' means '공단청구금'"""
        },
        {"role": "user", "content": f"""{ex_df}"""},
        {"role": "assistant", "content":f"""
                   1. 최근 3개월간 비급여 매출이 총 매출 대비 어느정도의 비중을 차지하고 있나요?' 이에 따른 전략을 어떻게 세워야할까요?
                   2. 최근 6개월간 총 환자수 대비 신규환자수 비중이 높아지고 있습니다. 새로운 마케팅전략을 사용하고 계시나요? 어떤 요인이 큰 작용을 하였나요?
                   3. 2020년 4월 기점으로 비급여 매출 진폭이 1달 간격으로 큰데, 원인이 뭐라고 생각하시는지요? 이를 위한 안정화 전략은 무엇으로 보고 계신지요?
                   4. 환자 재내원을 위한 원내 정책 어떤 것들 있으신가요? 준비된 시스템에 대한 서술 부탁드립니다.
                   5. 2020년 4월 비급여 매출이 가장 높네요. 한약 매출 최초,재결제 성과 노하우 상세한 말씀 부탁드립니다.
               """
        },
        {
            "role": "user",
            "content": f"""
            질문을 만들 때, 절대 테이블에 없는 이야기나, 테이블의 데이터와 일치하지 않는 정보는 언급하지 말아줘. 
            생성 예시 : {qs}
            데이터 테이블 :
            {msg}
            """
        }
    ]

    import openai
    openai.api_key="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"

    response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=conversation
    )

    for choice in response.choices:
        print(choice['message']['content'])

# %% [markdown]
# - 날질문
#   1. 최근 3개월간 공단 청구금이 매출 대비 어느정도의 비중을 차지하고 있나요? 비중이 높아지는 원인은 무엇인가요?
#   2. 2018년 10월 이후로 총 매출이 거의 6개월 동안 이전과 같이 유지되고 있습니다. 어떤 전략으로 새로운 고객층을 확보하려고 하시나요?
#   3. 2020년 1월 이후 비급여 매출이 급격히 증가하여 2월에는 총 매출 대비 35%에 해당합니다. 이에 따른 조치를 어떻게 취하고 계신가요?
#   4. 환자 만족도 조사에서 어떤 부분들이 가장 부족한 것으로 파악되고 있나요? 그리고, 이를 해결하기 위한 대책은 무엇인가요?
#   5. 2020년 2월 비급여 매출이 대폭 증가하였는데 이는 어떤 분야에서 발생한 것인가요? 이를 효율적으로 관리하기 위한 전략이 있으신가요?
#
# - 유사질문 (2개씩)
#   - 4월 한약 전환율이 높았던 요인은 무엇이었나요?
#   - 5월 자보지표 상승요인은 뭘까요?
#   - 예약환자 데이터 입력이 5월부터 입력이 안되고 있습니다. 어떤 상황이실까요?
#   - 1회성 약침 수가 변경이 있었나요?
#   - 주력 비급여 중 하나인 소아정신과의 매출 하락의 원인을 어떻게 평가하고 계신가요?
#   - 이번달 초진 환자와 재진 환자 감소 원인 어떻게 보고 계신가요?
#   - 4월 공진단 매출은 '5월 가정의 달'의 영향이 있었나요?
#   - 비급여 상담건수 줄어드는 원인은 어떻게 보세요?
#   - 비급여 항목에서 다이어트 패키지 아래 공란으로 있는 항목은 무엇인가요?
#   - 소개환자 유입율이 상승하고 있습니다. 원내에서 시행중이신 매뉴얼있으신가요? 있으시다면, 공유 부탁드립니다.
#
# - 최종질문
# 1. 최근 6개월간 비급여 매출이 전체 매출 대비 어느정도로 유지되고 있나요? 이에 따라 비급여 매출 비중이 중요한 의미를 가질 때, 이에 대한 대책을 어떻게 세우시는지 궁금합니다.
# 2. 환자 유입 방식 관련하여 2019년 11월 이후부터 2020년 3월까지 예약 환자 데이터 입력에 제한이 있었거나, 문제가 있었던 것으로 보이는데, 이에 대한 원인과 안정화를 위해 어떤 대책이 필요한지 여쭤봅니다.
# 3. 2018년 11월 이후, 2년간 비보험료 관련 매출이 큰 폭으로 감소하였습니다. 이에 따른 대응방안을 구체적으로 말씀 부탁드립니다.
# 4. 2020년 5월 이전에 비해 2020년 5월부터 총 환자수가 줄어들기 시작했습니다. 이 현상에 대한 이유와 앞으로의 대응 계획을 알려주세요.
# 5. 2019년 3월 총매출 대비 비보험료 매출 비중이 큰 폭으로 감소하는데, 이를 축적된 마케팅 전문성과 비교하여 평가하시는지요? 이에 따른 대응방안이 있으신지도 궁금합니다.
#
#
# #### :: 평가
# - 복합적인 질문들 수준 올라갔다.
# - 추론적 질문들도 많이 발전했다.
# - 사실에 최대한 근거되는 질문들을 만들으려면 프롬프트에 모든 컬럼을 소개해주는건 어떨까?

# %% [markdown]
# ## 5. 모든 column을 설명해주기

# %%
def gpt_answer(msg):

    openai.api_key="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"

    answer=[]

    # ex_df = pd.read_csv('/home/fastcampus/Gasan/codes/경창예시.csv')

    system_prompt ="""너는 주어진 정보를 보고 경영체의 발전을 위해 피드백 해주는 전문가야.
                     다음에 주어질 테이블 데이터를 종합하여 특이점과 변동하는 값들에 기반하여 
                     이 병원을 위한 피드백 질문 5개를 생성해줘. 구체적인 날짜를 언급해줘.
                        
                        Instructions:
                        - 'biz_dt'는 '날짜'야. 매월 1일에 바로 앞 달의 값을 구해서 적어.
                        - 'total_pay' means '총 매출'. 한의원의 한 달 총 매출이야. '비급여 총매출', '자보매출', '공단청구금', '본인부담금', '기타매출'을 합한 값이야.
                        - 'nonbenefit_total_pay' means '비급여 총매출'. 비급여 총매출은 환자가 100% 부담하는 비용이야. 한의원은 이 비급여항목의 매출을 유도하여 총 매출 상승을 노리는게 중요해.
                        - 'carinsur_pay' means '자보매출'. 자보매출은 한의원에 교통사고로 찾아온 환자들의 치료비를 자동차보험회사에서 제공해주는 매출이야.
                        - 'nhis_pay' means '공단청구금'. 공단청구금은 한의원에 찾아온 환자들이 가입한 건강관리공단등에서 비용을 병원에 지불해주는 매출이야.
                        - 'co_pay' means '본인부담금'. 본인부담금은 환자의 치료비에서 공단이나 보험에서 일부분을 지불해주고 남은 비용이야. 환자가 직접 병원에 지불하는 매출이야.
                        - 'etc_pay' means '기타매출'. 기타매출은 진료 이외의 부분에서 발생한 매출이야.
                        - 'visit_cnt' means '환자 수'. 환자 수는 한 달동안 병원에 찾아온 전체 환자 수를 의미해.
                        - 'fstvisit_cnt' means '신규 환자수'. 신규 환자수는 처음 병원을 찾아 온 환자의 수를 의미해.
                        
                        
                     """

    completion = openai.ChatCompletion.create(
        model = "gpt-3.5-turbo",
        messages=[{"role": "system", "content": system_prompt},
                #  {"role": "user", "content": f"""{ex_df}"""},
                #  {"role": "assistant", "content":f"""
                #    1. 최근 3개월간 비급여 매출이 총 매출 대비 어느정도의 비중을 차지하고 있나요?' 이에 따른 전략을 어떻게 세워야할까요?
                #    2. 최근 6개월간 총 환자수 대비 신규환자수 비중이 높아지고 있습니다. 새로운 마케팅전략을 사용하고 계시나요? 어떤 요인이 큰 작용을 하였나요?
                #    3. 2020년 4월 기점으로 비급여 매출 진폭이 1달 간격으로 큰데, 원인이 뭐라고 생각하시는지요? 이를 위한 안정화 전략은 무엇으로 보고 계신지요?
                #    4. 환자 재내원을 위한 원내 정책 어떤 것들 있으신가요? 준비된 시스템에 대한 서술 부탁드립니다.
                #    5. 2020년 4월 비급여 매출이 가장 높네요. 한약 매출 최초,재결제 성과 노하우 상세한 말씀 부탁드립니다.
                #     """},
                   {"role": "user", "content":f"""{msg}"""}]
    )

    for choice in completion.choices:
        print(choice['message']['content'])
        answer.append(choice['message']['content'].strip())

    return answer

# %%
def gpt_final(msg, qs):
    
    # ex_df = pd.read_csv('/home/fastcampus/Gasan/codes/경창예시.csv')

    conversation = [
        {
            "role": "system",
            "content": """너는 주어진 정보를 보고 경영체의 발전을 위해 피드백 해주는 전문가야.
                     다음에 주어질 테이블 데이터를 종합하여 특이점과 변동하는 값들에 기반하여 
                     이 병원을 위한 피드백 질문 5가지를 생성해줘. 구체적인 날짜를 언급해줘.
                     너의 질문들의 형태는 주어지는 '생성 예시'의 말투와 비슷하게 추론적인 질문들을 만들어줘.
                     질문은 한가지 영역에 관한 단순한 질문이 아닌, 모든 영역의 지표들을 종합적으로 고려해서 만들어줘.
                            
                           Instructions:
                        - 'biz_dt'는 '날짜'야. 매월 1일에 바로 앞 달의 값을 구해서 적어.
                        - 'total_pay' means '총 매출'. 한의원의 한 달 총 매출이야. '비급여 총매출', '자보매출', '공단청구금', '본인부담금', '기타매출'을 합한 값이야.
                        - 'nonbenefit_total_pay' means '비급여 총매출'. 비급여 총매출은 환자가 100% 부담하는 비용이야. 한의원은 이 비급여항목의 매출을 유도하여 총 매출 상승을 노리는게 중요해.
                        - 'carinsur_pay' means '자보매출'. 자보매출은 한의원에 교통사고로 찾아온 환자들의 치료비를 자동차보험회사에서 제공해주는 매출이야.
                        - 'nhis_pay' means '공단청구금'. 공단청구금은 한의원에 찾아온 환자들이 가입한 건강관리공단등에서 비용을 병원에 지불해주는 매출이야.
                        - 'co_pay' means '본인부담금'. 본인부담금은 환자의 치료비에서 공단이나 보험에서 일부분을 지불해주고 남은 비용이야. 환자가 직접 병원에 지불하는 매출이야.
                        - 'etc_pay' means '기타매출'. 기타매출은 진료 이외의 부분에서 발생한 매출이야.
                        - 'visit_cnt' means '환자 수'. 환자 수는 한 달동안 병원에 찾아온 전체 환자 수를 의미해.
                        - 'fstvisit_cnt' means '신규 환자수'. 신규 환자수는 처음 병원을 찾아 온 환자의 수를 의미해.
                        """
        },
        # {"role": "user", "content": f"""{ex_df}"""},
        # {"role": "assistant", "content":f"""
        #            1. 최근 3개월간 비급여 매출이 총 매출 대비 어느정도의 비중을 차지하고 있나요?' 이에 따른 전략을 어떻게 세워야할까요?
        #            2. 최근 6개월간 총 환자수 대비 신규환자수 비중이 높아지고 있습니다. 새로운 마케팅전략을 사용하고 계시나요? 어떤 요인이 큰 작용을 하였나요?
        #            3. 2020년 4월 기점으로 비급여 매출 진폭이 1달 간격으로 큰데, 원인이 뭐라고 생각하시는지요? 이를 위한 안정화 전략은 무엇으로 보고 계신지요?
        #            4. 환자 재내원을 위한 원내 정책 어떤 것들 있으신가요? 준비된 시스템에 대한 서술 부탁드립니다.
        #            5. 2020년 4월 비급여 매출이 가장 높네요. 한약 매출 최초,재결제 성과 노하우 상세한 말씀 부탁드립니다.
        #        """
        # },
        {
            "role": "user",
            "content": f"""
            질문을 만들 때, 절대 테이블에 없는 이야기나, 테이블의 데이터와 일치하지 않는 정보는 언급하지 말아줘. 
            생성 예시 : {qs}
            
            데이터 테이블 :
            {msg}
            """
        }
    ]

    import openai
    openai.api_key="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"

    response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=conversation
    )

    for choice in response.choices:
        print(choice['message']['content'])

# %% [markdown]
# #### :: 토큰제한으로 few-shot은 하지 않았다!
#
# - 날질문
#   1. 왜 2018년 9월과 10월에 비급여 총매출이 갑자기 증가하였을까?
#   2. 공단청구금에서 2018년 12월과 2019년 1월에 급격한 감소가 있었는데 이에 대한 이유는 무엇인가?
#   3. 본인부담금이 2019년 5월과 6월에 비정상적으로 높은데, 이 고객층은 어떤 특징이 있을까?
#   4. 2019년 3월에 방문한 환자 수가 급격히 증가하였는데, 어떤 홍보/ 마케팅 활동을 한 것일까?
#   5. 2018년 12월과 2019년 5월에 자동차보험금이 비정상적으로 높은데, 이는 차이가 나는 이유는 무엇일까?
#
#   ##(4.0 인데 미쳤네 퀄리티 너무 좋은 질문들)
#   1. 2018년 9월과 10월에 총 매출이 급격하게 상승한 이유가 무엇인가요? 이 기간 동안 특별한 활동이나 행사를 개최하셨나요?
#   2. 2019년 4월과 5월에 자보매출이 각각 7515240.0, 9496820.0로 상승한 원인이 무엇인지 확인해주실 수 있나요? 교통사고 환자가 많이 발생한 것인지, 다른 이유가 있는 지 궁금합니다.
#   3. 2019년 9월과 2019년 10월에는 환자 수가 감소하면서 신규 환자수는 증가하여 전환율이 좋아졌습니다. 이 기간 동안 병원이 취한 신규 환자 확보 전략이 무엇인지 알려주세요.
#   4. 2020년 1월에 총 매출이 전월보다 급격히 하락한 이유와 그 원인을 파악해주실 수 있나요? 특정 원인이 없다면, 전반적인 매출액 감소 원인들을 분석 및 개선 방안을 제시해주세요.
#   5. 2020년 2월에 비급여 총매출이 14611010.0으로 전월 대비 상승한데 반해, 환자 수는 728명으로 하락했습니다. 이 기간 동안 특정한 비급여 발생 사례나 아이템이 있었는지 확인 부탁드립니다.
#
# - 유사질문
#     '비급여 매출 2월 하락요인과 개선 전략은?',
#     '환자수변동폭은 크지 않은데 비급여 매출이 40% 가량 상승, 어떤 전략이 있었나?',
#     '신환 회복을 위한 전략으로 리뷰이벤트, 소개이벤트 등 고려해보셨을까요?',
#     '비급여 매출 2월 하락요인과 개선 전략은?',
#     '치료 한약 2배 가까이 됐는데, 세부 지표로 나누시면 어떤 항목이 오르신 걸까요?',
#     '데스크 예약 접수율 하락된 요인은 무엇일까요?',
#     '3월 이후 만성통증 한약 매출이 발생했습니다. 데이터 기입 오류일까요? 그리고 6월달 다이어트가 왜 낮게 나왔을까요',
#     '지금 남아있는 직원 구성이 어떻게 될까요? 실장은 이미 나간 상태인가요? 공고글 한번 공유주실 수 있을까요?',
#     '지금 남아있는 직원 구성이 어떻게 될까요? 실장은 이미 나간 상태인가요? 공고글 한번 공유주실 수 있을까요?',
#     '데스크 예약 접수율 하락된 요인은 무엇일까요?'
#
# - 최종질문
#   1. 2020년 2월, 비급여 총매출이 총 매출 중 높은 비중을 차지하고 있습니다. 이는 어떤 이유 때문인가요?
#   2. 2019년 6월 대비 2019년 11월, 본인부담금 매출 비중이 감소했습니다. 이에 대한 이유는 무엇일까요?
#   3. 최근 전체적인 환자수는 큰 차이가 없는 것으로 보입니다. 그러나 비급여 총매출은 상승하고 있습니다. 이유가 무엇이라고 생각하시나요?
#   4. 2020년 2월, 비급여 총매출이 1월 대비 감소했습니다. 이러한 변동 원인을 찾을 수 있나요?
#   5. 신규 환자수가 많은 한의원입니다. 그러나 2019년 6월 대비 2019년 11월, 신규 환자수가 감소한 것으로 나타났습니다. 이에 대한 개선 방안이 있을까요?
#
# #### :: 평가
# - 사실에 근거한 질문은 훨씬 좋아진것 같다.
# - 훨씬 질문이 입체적인 느낌.

# %% [markdown]
# ## 6. 없는 정보 언급 X prompt 추가// 특이점 추가

# %%
def gpt_answer(msg):

    openai.api_key="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"

    answer=[]


    system_prompt ="""
                     너는 주어진 정보를 보고 경영체의 발전을 위해 피드백 해주는 전문가야.
                     주어질 테이블 데이터를 종합적으로 분석하여 큰 특징들, 또는 추세에 기반하여  
                     이 병원을 위한 피드백 질문 5개를 생성해줘. 구체적인 날짜를 언급해줘.
                     데이터 테이블에 없는 내용은 언급하지 마.
                        
                        Instructions:
                        - 'biz_dt'는 '날짜'야. 매월 1일에 바로 앞 달의 값을 구해서 적어.
                        - 'total_pay' means '총 매출'. 한의원의 한 달 총 매출이야. '비급여 총매출', '자보매출', '공단청구금', '본인부담금', '기타매출'을 합한 값이야.
                        - 'nonbenefit_total_pay' means '비급여 총매출'. 비급여 총매출은 환자가 100% 부담하는 비용이야. 한의원은 이 비급여항목의 매출을 유도하여 총 매출 상승을 노리는게 중요해.
                        - 'carinsur_pay' means '자보매출'. 자보매출은 한의원에 교통사고로 찾아온 환자들의 치료비를 자동차보험회사에서 제공해주는 매출이야.
                        - 'nhis_pay' means '공단청구금'. 공단청구금은 한의원에 찾아온 환자들이 가입한 건강관리공단등에서 비용을 병원에 지불해주는 매출이야.
                        - 'co_pay' means '본인부담금'. 본인부담금은 환자의 치료비에서 공단이나 보험에서 일부분을 지불해주고 남은 비용이야. 환자가 직접 병원에 지불하는 매출이야.
                        - 'etc_pay' means '기타매출'. 기타매출은 진료 이외의 부분에서 발생한 매출이야.
                        - 'visit_cnt' means '환자 수'. 환자 수는 한 달동안 병원에 찾아온 전체 환자 수를 의미해.
                        - 'fstvisit_cnt' means '신규 환자수'. 신규 환자수는 처음 병원을 찾아 온 환자의 수를 의미해.
                        
                        
                     """

    completion = openai.ChatCompletion.create(
        model = "gpt-3.5-turbo",
        messages=[{"role": "system", "content": system_prompt},
                   {"role": "user", "content":f"""{msg}"""}]
    )

    for choice in completion.choices:
        print(choice['message']['content'])
        answer.append(choice['message']['content'].strip())

    return answer

# %%
def gpt_final(msg, qs):

    conversation = [
        {
        "role": "system",
        "content": f"""너는 주어진 정보를 보고 경영체의 발전을 위해 피드백 해주는 전문가야.
                     주어질 테이블 데이터를 종합적으로 분석하여 큰 특징들, 또는 추세에 기반하여  
                     이 병원을 위한 피드백 질문 5개를 생성해줘. 구체적인 날짜를 언급해줘.
                     데이터 테이블에 없는 내용은 언급하지 마.
                     '특이점_예시'는 너가 찾아야 하는 테이블의 특이점들의 예시야. 
                     절대 '특이점_예시'의 말투를 그대로 따라하거나, 테이블의 데이터와 다른 이야기는 하지마.
                     절대로 이야기를 만들어내지 말고 테이블 데이터에 기반해서 특이점을 찾아야해.
                    
                     '특이점_예시':
                     1. 최근 3개월 "신규환자수/총환자수 비율(%)"이 약 9%로 높습니다.
                     2. 2020년의 총매출은 전년도에 비해 많이 감소하였으나 최근 3개월간 회복세에 있습니다.
                     3. 2019년 3월과 2020년 4월에 "비급여 총매출","총 매출","환자 수"의 지표가 눈에 띄게 증가했습니다.
                     4. 최근 3개월 "비급여 총매출"은 감소하나, "신규 환자수"는 증가하는 추세입니다.
                     5. 2020년 3월에 "비급여 총매출","총 매출","환자 수"의 지표가 매우 낮게 나왔습니다.
                     6. 최근 3개월 "비급여/총매출 비율(%)"이 비교적 매우 높게 나왔다.
                     7. 신규 환자수는 2018년 7월과 2018년 8월에 각각 87명, 93명으로 가장 높게 발생하였다.


                     너의 질문들의 형태는 주어지는 '생성 예시'의 말투와 비슷하게 추론적인 질문들을 만들어줘.
                     이때, '생성 예시'의 단어들까지 따라할 필요는 없어.
                     질문은 한가지 영역에 관한 단순한 질문이 아닌, 모든 영역의 지표들을 종합적으로 고려해서 만들어줘.
                     질문을 만들 때, 절대 테이블에 없는 이야기나, 테이블의 데이터와 일치하지 않는 정보는 언급하지 말아줘. 
 
        
                     '생성 예시' : {qs}
        
                    Instructions:
                    - 'biz_dt'는 '날짜'야. 매월 1일에 바로 앞 달의 값을 구해서 적어.
                    - 'total_pay' means '총 매출'. 한의원의 한 달 총 매출이야. '비급여 총매출', '자보매출', '공단청구금', '본인부담금', '기타매출'을 합한 값이야.
                    - 'nonbenefit_total_pay' means '비급여 총매출'. 비급여 총매출은 환자가 100% 부담하는 비용이야. 한의원은 이 비급여항목의 매출을 유도하여 총 매출 상승을 노리는게 중요해.
                    - 'carinsur_pay' means '자보매출'. 자보매출은 한의원에 교통사고로 찾아온 환자들의 치료비를 자동차보험회사에서 제공해주는 매출이야.
                    - 'nhis_pay' means '공단청구금'. 공단청구금은 한의원에 찾아온 환자들이 가입한 건강관리공단등에서 비용을 병원에 지불해주는 매출이야.
                    - 'co_pay' means '본인부담금'. 본인부담금은 환자의 치료비에서 공단이나 보험에서 일부분을 지불해주고 남은 비용이야. 환자가 직접 병원에 지불하는 매출이야.
                    - 'etc_pay' means '기타매출'. 기타매출은 진료 이외의 부분에서 발생한 매출이야.
                    - 'visit_cnt' means '환자 수'. 환자 수는 한 달동안 병원에 찾아온 전체 환자 수를 의미해.
                    - 'fstvisit_cnt' means '신규 환자수'. 신규 환자수는 처음 병원을 찾아 온 환자의 수를 의미해.
                    """
    },
        {
            "role": "user",
            "content": f"""
                데이터 테이블: {msg}
            """
        }
    ]

    import openai
    openai.api_key="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"

    response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=conversation
    )

    for choice in response.choices:
        print(choice['message']['content'])

# %% [markdown]
# - 날질문
# 1. 한의원의 총 매출은 점차 감소하는 지향성을 보이고 있는데, 이에 대한 대응책은 어떻게 될까요? (2018년 9월 ~ 2019년 12월)
# 2. 2018년 10월과 2019년 7월, 8월에는 공단 청구금에서 큰 차이가 나타나는데, 그 원인은 무엇인가요?
# 3. 2019년 1월과 2월에는 비급여 총매출이 크게 증가했는데, 이유를 알 수 있을까요?
# 4. 자동차보험에서 제공하는 자보매출이 2019년 6월에 1년간 최대치를 기록했는데, 2019년 6월에 무슨 일이 있었나요?
# 5. 처음 병원을 찾아온 신규 환자수가 2019년 5월과 2019년 7월, 8월에 증가했는데, 이에 대한 이유는 무엇인가요?
#
# - 유사질문
# '한약 매출이 줄었습니다. 비급여 하락 요인 어떻게 보고 계신가요? 잘 됐을 때와, 줄었을 때 차별점이 무엇인지, 어떻게 생각하고 계실까요? 그리고 통녹용한약이 무엇인지 여쭤봅니다.',
#  '일평환 우상향 중입니다. 데스크예약율도 상승세이어지고 있고요. 어떤 부분이 안정화되었을까요?',
#  '신환 회복을 위한 전략으로 리뷰이벤트, 소개이벤트 등 고려해보셨을까요?',
#  '이번달 다이어트 매출 줄어든 원인은 뭘까요?',
#  '이번달 일반한약 상담건수가 왜 줄었을까요?',
#  '다른 사람들에게 공유하고 싶으신 인사이트 내용 세션에서 상세 공유부탁드립니다. ',
#  '데스크 예약 접수율 하락된 요인은 무엇일까요?',
#  '최근 3년간 가장 높은 2월의 매출입니다. 회고했을 때 어떤 점이 개선되었다고 보시나요? 장기적 관점에서 원내 고도화 필요한 부분도 함께 말씀부탁드려요.',
#  '지금 남아있는 직원 구성이 어떻게 될까요? 실장은 이미 나간 상태인가요? 공고글 한번 공유주실 수 있을까요?',
#  '재초진 환자수 상승 주요인이 뭘까요? 환자 회귀현상에 대해 어떻게 보고 계신지요?'
#
#
# - 최종
# 1. 최근 3개월 간의 '신규 환자수'가 이전 3개월 대비 증가했는가? 어떤 원인이 이러한 변화를 야기했나요? (2020년 12월 ~ 2021년 2월)
# 2. 2020년 3월에 '비급여 총매출', '총 매출', '환자 수'의 지표가 낮게 나왔는데, 이에 대한 대처 방안은 무엇인가요? (2020년 3월)
# 3. 최근 3개월 '비급여/총매출 비율(%)'이 이전 3개월 대비 높게 나왔다는데, 이러한 추세는 어떤 원인으로 인해 발생한 것인가요? (2021년 1월 ~ 2021년 3월)
# 4. 2020년 총매출은 전년도 대비 감소한 것으로 나왔지만, 최근 3개월간 회복세를 보이고 있다는데, 이러한 변화는 어떤 요인으로 인해 발생한 것인가요? (2020년 12월 ~ 2021년 2월)
# 5. 2019년 3월과 2020년 4월에 "비급여 총매출", "총 매출", "환자 수"의 지표가 눈에 띄게 증가한 이유가 무엇인가요? 이러한 지표 상승을 유지하기 위한 대책은 무엇인가요?

# %% [markdown]
# ## 7. 영어로만들어보기

# %%
def gpt_answer(msg):

    openai.api_key="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"

    answer=[]


    system_prompt ="""
                     You are an expert who gives feedback for the development of management, with some informations about that management.
                     You will receive data table.
                     Make several comprehensive analysis of the datas, especially based on some characteristics and overall trends of the data.
                     Then make 5 questions that contains the analysis you made, including specific dates of the data.
                     For each questions, add the reason why you made that question, based on the analysis you made by data.
                     All your questions should be based on the given data table, so never mention the information that is not given by the data.
                     Don't make questions that asks obvious information on data, but rather make comprehensive(reason-asking) ones.
                     Your answer should be in Korean.
                        
                        Instructions:
                        - 'biz_dt' means '날짜'.
                        - 'total_pay' means '총 매출'. It's total sales of medical clinic for a month. It's the sum of '비급여 총매출', '자보매출', '공단청구금', '본인부담금', '기타매출'.
                        - 'nonbenefit_total_pay' means '비급여 총매출'. This sales are paid by patient 100%.It is important for medical clinics to induce sales of these items to increase total sales.
                        - 'carinsur_pay' means '자보매출'. These sales are sales that auto insurance companies provide medical expenses for patients who come to medical clinics due to traffic accidents.
                        - 'nhis_pay' means '공단청구금'. These sales are paid by the Health Care Corporation, etc., which patients who visited the medical clinic joined.
                        - 'co_pay' means '본인부담금'. These are the remaining expenses after paying a portion of the patient's medical expenses from the corporation or insurance. It's the sales that the patient pays directly to the hospital.
                        - 'etc_pay' means '기타매출'. These are sales that occurred outside of medical treatment.
                        - 'visit_cnt' means '환자 수'. This indicates the total number of patients who visited the hospital for a month.
                        - 'fstvisit_cnt' means '신규 환자수'. This indicates the number of patients who visited the hospital for the first time.
                        
                        
                     """

    completion = openai.ChatCompletion.create(
        model = "gpt-3.5-turbo",
        messages=[{"role": "system", "content": system_prompt},
                   {"role": "user", "content":f"""{msg}"""}]
    )

    for choice in completion.choices:
        print(choice['message']['content'])
        answer.append(choice['message']['content'].strip())

    return answer

# %% [markdown]
# - 날질문
# 1. 2018년 10월 대비 2018년 11월 비급여 총매출의 증감 비교는 어떠한가요? 그 이유는 무엇일까요?
# 2. 2019년 3월, 환자 수(방문자 수)가 가장 높은 월입니다. 비교적 많은 환자가 발생한 이유는 무엇일까요?
# 3. 2019년 상반기(1월~6월)와 하반기(7월~12월)의 방문한 환자 수(fstvisit_cnt)는 어떻게 되나요? 이 차이가 발생한 이유는 무엇일까요?
# 4. 2018년 12월의 총 매출 대비 환자 수(visit_cnt)는 2019년 11월의 환자 수 대비 총 매출에서 어떠한 차이점이 보이나요? 그 이유는 무엇일까요?
# 5. 자보매출(carinsur_pay)이 비급여 총매출(nonbenefit_total_pay)보다 2018년 12월~2020년 2월 기간 중 가장 높은 달은 언제이며, 그 달에는 어떤 사고가 많이 발생했을까요?

# %% [markdown]
# (특징)
# 주어진 데이터를 바탕으로 종합적인 분석을 통해 주어진 매출액의 경향성과 특징을 파악할 수 있습니다. 주어진 데이터를 살펴보면 월별 매출액이 전반적으로 증가하는 추세를 보입니다. 그 중에서 환자가 일정 수준 이상 방문한 환자들이 기여한 수익이 주요한 비중을 차지합니다. 비급여총매출도 전반적으로 증가하는 추세이지만 그 비중은 총매출 중 약 30% 정도이며 자보매출과 공단청구금의 비중은 10% 내외로 안정적인 경향을 보입니다.
#
# 기간에 따라 환자 수가 크게 달라지지 않는 것으로 보아 해당 병원의 고객 인식이 비교적 안정적인 것으로 파악됩니다. 새로운 방문자 수도 전반적으로 안정적으로 유지되어 환자 유치에 성공한 병원으로 평가할 수 있습니다.
# - 날질문

# %% [markdown]
# ## 8. gpt 4.0 만들어보기

# %%
def gpt_answer(msg):

    openai.api_key="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"

    answer=[]


    system_prompt ="""
                     You are an expert who gives feedback for the development of management, with some informations about that management.
                     You will receive data table.
                     Make several comprehensive analysis of the datas, especially based on some characteristics and overall trends of the data.
                     Then make 5 questions that contains the analysis you made, including specific dates of the data.
                     This questions should basically based on most recent values of the table.
                     For each questions, add the reason why you made that question, based on the analysis you made by data.
                     All your questions should be based on the given data table, so never mention the information that is not given by the data.
                     Don't make questions that asks obvious information on data, but rather make comprehensive(reason-asking) ones.
                     Your answer should be in Korean.
                        
                        Instructions:
                        - 'biz_dt' means '날짜'.
                        - 'total_pay' means '총 매출'. It's total sales of medical clinic for a month. It's the sum of '비급여 총매출', '자보매출', '공단청구금', '본인부담금', '기타매출'.
                        - 'nonbenefit_total_pay' means '비급여 총매출'. This sales are paid by patient 100%.It is important for medical clinics to induce sales of these items to increase total sales.
                        - 'carinsur_pay' means '자보매출'. These sales are sales that auto insurance companies provide medical expenses for patients who come to medical clinics due to traffic accidents.
                        - 'nhis_pay' means '공단청구금'. These sales are paid by the Health Care Corporation, etc., which patients who visited the medical clinic joined.
                        - 'co_pay' means '본인부담금'. These are the remaining expenses after paying a portion of the patient's medical expenses from the corporation or insurance. It's the sales that the patient pays directly to the hospital.
                        - 'etc_pay' means '기타매출'. These are sales that occurred outside of medical treatment.
                        - 'visit_cnt' means '환자 수'. This indicates the total number of patients who visited the hospital for a month.
                        - 'fstvisit_cnt' means '신규 환자수'. This indicates the number of patients who visited the hospital for the first time.
                        
                        
                     """

    completion = openai.ChatCompletion.create(
        model = "gpt-3.5-turbo",
        messages=[{"role": "system", "content": system_prompt},
                   {"role": "user", "content":f"""{msg}"""}]
    )

    for choice in completion.choices:
        print(choice['message']['content'])
        answer.append(choice['message']['content'].strip())

    return answer

# %%
데이터를 분석한 결과 다음과 같은 특성과 트렌드를 확인하였습니다:

'총 매출'은 시간이 지남에 따라 전반적으로 증가하는 경향을 보이며, 특히 '비급여 총매출'이 많은 비중을 차지하는 것을 확인할 수 있습니다.
'자보매출'이 크게 변동하는 것으로 보아, 교통사고로 인한 환자 방문이 클리닉의 매출에 영향을 미치는 것 같습니다.
월별 '환자 수'와 '신규 환자수'는 상대적으로 안정적인 수준을 유지하고 있습니다.
'본인부담금'과 '기타매출'은 변동성이 거의 없으며, 그 비중은 상대적으로 작습니다.
이러한 분석 결과를 바탕으로 다음과 같은 질문을 제시하겠습니다:

1. 2020년 2월에 '비급여 총매출'이 전월 대비 상승한 이유는 무엇인가요?
- 이 질문은 '비급여 총매출'이 매출 중 큰 비중을 차지하고 있으며, 특정 월에 이 부분의 매출이 증가한 이유를 파악함으로써 전체 매출 증가에 기여한 요인을 이해하려는 목적에서 제시하였습니다.
2. '자보매출'이 상대적으로 높은 2019년 12월에 특별한 이벤트나 사건이 있었나요?
- '자보매출'의 큰 변동성을 고려할 때, 교통사고 환자 수의 변동이 이를 좌우하는 것으로 판단하였습니다. 이 질문은 그 원인을 파악하기 위한 것입니다.
3. 2020년 2월에 '환자 수'와 '신규 환자수'가 감소한 원인은 무엇인가요?
- 이 질문은 월별 방문 환자 수의 변화를 파악하고, 이러한 변화가 전체 매출에 어떠한 영향을 미치는지 이해하기 위해 제기하였습니다.
4. 전체 '총 매출' 중 '본인부담금'과 '기타매출'의 비중이 상대적으로 낮은 이유는 무엇인가요?
- 이 질문은 매출 구성요소 중 '본인부담금'과 '기타매출'의 비중이 다른 요소에 비해 상대적으로 작은 이유를 이해하려는 목적에서 제시하였습니다.
5. 2020년 1월부터 2월 사이에 '공단청구금'이 감소한 이유는 무엇인가요?
- 이 질문은 기관이나 보험에서 지급하는 '공단청구금'이 어떠한 원인으로 인해 감소하였는지를 이해하려는 목적에서 제시하였습니다. 이것은 보험 청구 절차의 변경, 보험 혜택의 감소 등 다양한 가능성을 탐색해 볼 수 있습니다.

# %%
## 동일한 프롬프트로 3.5

1. 최근 몇 달간 비급여 총 매출은 전체 매출 중 어느 정도의 비중을 차지하고 있으며, 이 비중의 증감 추이는 어떻게 나타나고 있는가? (2020년 2월 기준)
- 비급여 총 매출은 전체 매출 중 35.5%의 비중을 차지하고 있다. 이는 2020년 2월 기준으로 비교적 꾸준히 유지되었다.
- 이전 달(2020년 1월) 비교시 비급여 총 매출 비중은 약 0.2% 상승하여 일정한 증가 추세가 있으며, 향후 추이를 지켜봐야 할 문제이다.

2. 최근 3개월간 대형 자동차 사고로 인한 자보 매출 증감 추이는 어떻게 나타나고 있는가? (2020년 2월 기준)
- 자보 매출은 2019년 12월 이후 2달 간 증가세를 보이다 2020년 2월에 큰 폭의 감소세를 보였다.
- 최근 3개월간 자보 매출은 큰 폭의 변동이 있었으며, 이전 달(2020년 1월)보다 0.3% 줄어든 수치를 기록하고 있다.

3. 최근 3개월간 본인 부담금의 비중은 어떻게 나타나고 있는가? (2020년 2월 기준)
- 본인 부담금의 비중은 2020년 2월 기준 16.3%로 전반적으로 일정한 수준을 유지하고 있다.
- 2019년 12월부터 2020년 2월까지 비교하여 1% 이하의 증감으로 안정적인 추이를 보이고 있다.

4. 금월(2020년 2월)의 총 매출 대비 환자 수는 어떻게 나타나고 있는가?
- 2020년 2월 환자 수는 728명으로, 금월의 총 매출 대비 약 1,000,000원을 기록하는 것으로 나타났다.
- 이는 이전 월(2020년 1월) 대비 64명 증가하였으며, 총 매출 대비 환자 수 추이를 지켜봐야 할 것이다.

5. 기간 내 전반적인 신규 환자 수 증감 추이는 어떻게 나타나고 있는가? (2018년 9월부터 2020년 2월)
- 신규 환자 수는 2018년 9월부터 2019년 6월까지 감소세를 보이다 2019년 8월부터 2달 간 큰 폭의 증가세를 보인 후, 2019년 11월부터 2020년 2월까지 안정적인 추이를 이어가고 있다.
- 특히 기간 내 급격한 증감을 보인 월은 없으며, 전반적인 안정성을 보이고 있다.

# %%
2020년 2월의 비급여 총매출이 2019년 12월보다 많이 증가한 이유는 무엇인가요?
분석 이유: 비급여 총매출이 급격히 증가한 것은 이전 몇 개월 간의 패턴과 다르므로, 그 원인을 파악하는 것이 중요합니다.

2019년 12월에 자보매출이 크게 증가한 이유는 무엇인가요?
분석 이유: 자보매출의 급격한 증가는 다른 월과는 다르게 보이며, 이로 인해 총 매출에 큰 영향을 미쳤을 가능성이 있습니다.

2019년 9월에 환자 수가 감소한 이유는 무엇인가요?
분석 이유: 환자 수가 급감한 월이 있었는데, 이는 총 매출에 영향을 미쳤을 것이므로 이유를 알아보는 것이 중요합니다.

2019년 7월에 공단청구금 매출이 이전 달보다 감소한 이유는 무엇인가요?
분석 이유: 공단청구금이 이전 달에 비해 감소한 원인을 알아보는 것이 필요합니다. 공단청구금은 환자의 질병 상태나 치료 방법 등에 따라 변동될 수 있습니다.

본인부담금 매출이 점차 감소하는 추세를 보이는데, 이에 대한 원인은 무엇인가요?
분석 이유: 본인부담금 매출은 환자의 부담을 나타내는 중요한 지표로, 이 값의 변화는 환자의 이용 패턴에 대한 중요한 정보를 제공합니다.

# %% [markdown]
# ## feedback
